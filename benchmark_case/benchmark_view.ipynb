# %%
from wikihop_dataset import WikiHopQADataset
wikihop_ds_path = "/mnt/data/gyzou/expr_workplace/self-agent-memory/benchmark_cache/manual_hf_download/2wikihopqa/data"
wikihop_ds = WikiHopQADataset(wikihop_ds_path)

wikihop_ds.load_data("dev")

dev_data = wikihop_ds.get_data("dev")

print(len(dev_data))
print(dev_data[0].keys())
print(dev_data[0])
# Out:
# 已加载验证集: 12576 条记录
# 12576
# dict_keys(['_id', 'type', 'question', 'context', 'supporting_facts', 'evidences', 'answer'])
# ...

# %%
from memory_benchmark_dataset import get_ttl_ds

ttl_ds = get_ttl_ds()
view_idx = 0
print(ttl_ds[view_idx]['context'])
print(ttl_ds[view_idx]['questions'])
print(ttl_ds[view_idx]['answers'])
# Out:
# I've already tried 5 times to complete a transfer that's just standard. What's the deal? Is your system down at this time?
# label: 73
#
# I would like some more physical cards, what is my limit?
# label: 71
#
# If I don't live in the UK, can I still get a card?
# label: 11
#
# What's going on with my balance? Shouldn't it be a bit higher since I deposited a cheque a day ago?
# label: 4
#
# Do you know how I can verify that I did a top-up to my card?
# label: 34
#
# How do I deposit through bank transfer?
# label: 52
#
# Is there a top-up limit that I have to stay under during a given period of time?
# label: 14
#
# should i add money via bank transfer instead
# label: 76
#
# Why isn't my purchase exchange rate correct?
# label: 19
#
# I got a message that my transfer was declined.
# label: 29
#
# Which fiat currencies are compatible for exchange and holding?
# label: 56
#
# Why hasn't my transaction completed?
# label: 6
#
# ...
